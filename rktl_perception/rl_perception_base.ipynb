# %%
import ultralytics
from ultralytics import YOLO
import math
import matplotlib.pyplot as plt
# import rotpy
# import rotpy
import cv2
import numpy as np
#from rotpy.system import SpinSystem
#from rotpy.camera import CameraList
import matplotlib.pyplot as plt
import cv2
import numpy as np
from IPython.display import display, Image
import ipywidgets as widgets
import threading

# %%
model = YOLO("best.pt")  # load anofficial model

# %%
import pyflycap2 as pyfc

# %%
import rclpy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5276\1793537503.py in <module>
# ----> 1 import rclpy
#
# ModuleNotFoundError: No module named 'rclpy'

# %%
import os

# %%
import cv2
import math
import robotpy_apriltag  # Import from pupil-apriltags
from pupil_apriltags import Detector

# Initialize the camera
cap = cv2.VideoCapture(1)
# cap.set(3, 640)  # adjust width
# cap.set(4, 480)  # adjust height

# Initialize the AprilTag detector from pupil-apriltags
#os.add_dll_directory("C:/Users/zakol/anaconda3/Newfolder/lib/site-packages/pupil_apriltags/lib")
#"C:/Users/username/Miniconda3/envs/my_env/lib/site-packages/pupil_apriltags.libs"

#at_detector = Detector()

# Assuming your model is already loaded and initialized
# model = torch.load('your_model.pt') 
# model.eval()
#system = SpinSystem()
#cameras = CameraList.create_from_system(system, True, True)
#cameras.get_size()
#camera = cameras.create_camera_by_serial('15374755')
#camera.init_cam()
# the names of the pixel formats available for the camera
#camera.camera_nodes.PixelFormat.get_entries_names()
classNames = ['ball']  # Replace with your actual class names
#camera.camera_nodes.PixelFormat.set_node_value_from_str('RGB8')  # or 'Y16' for 16-bit grayscale

#camera.end_acquisition()

while True:
    
    #success, img = cap.read()
    
    #camera.begin_acquisition()
    #image_cam = camera.get_next_image()
    #img = np.array(image_cam.get_image_data())
    #image_cam.release()

    #camera.end_acquisition()
    ret, img = cap.read()
    #img = img.reshape(964, 1288, 3)
    #img = img[:, :, ::-1]
    #if not success:
    #   break
    print(img.shape)
    # ---- 1. Run inference with your trained model ----
    results = model(img, stream=True)
    print(results)
    # Process the model's object detection results

    # ---- 2. AprilTag detection using pupil-apriltags ----
    # Convert the frame to grayscale for AprilTag detection
    #detector = robotpy_apriltag.AprilTagDetector()
    #detector.addFamily("tag25h9", 3)

    detector = Detector(families = 'tag25h9')
    gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    base_x = 0.0
    base_y = 0.0
    len_side = 1.0
    tags = detector.detect(gray_image)
    print(len(tags))
    # Draw bounding boxes around detected AprilTags
    tags.sort(key = lambda x: x.tag_id, reverse = False)
    
    for i, tag in enumerate(tags):
        if i == 0:
            # Compute pixel side length using corners 0 and 1
            x0, y0 = tag.corners[0]
            x1, y1 = tag.corners[1]
            side_len_pix = ((x0 - x1) ** 2 + (y0 - y1) ** 2) ** 0.5
            len_side = -1 * 7.75 / side_len_pix  # scaling factor from your original code
            base_x, base_y = tag.center
    
        if base_x is None or base_y is None or len_side is None:
            # Skip tags before the base tag is found
            continue
    
        labx = round((tag.center[0] - base_x) * len_side, 2)
        laby = round((tag.center[1] - base_y) * len_side, 2)
        labt = f"({labx}, {laby})"
    
        # Draw lines between corners
        for i in range(4):
            j = (i + 1) % 4
            point1 = (int(tag.corners[i][0]), int(tag.corners[i][1]))
            point2 = (int(tag.corners[j][0]), int(tag.corners[j][1]))
            cv2.line(img, point1, point2, (255, 0, 255), 2)
    
        cx = int(tag.center[0])
        cy = int(tag.center[1])
        ll = 10
        cv2.putText(img, str(tag.tag_id), (cx + ll, cy), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 0),thickness = 2)
        cv2.putText(img,  labt , (cx + 12, cy + 12), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 0),thickness = 2)
        #cv2.putText(img,  labt2 , (cx + 12, cy + 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (10, 10, 100),thickness = 1)



        # Display the tag ID at the center of the tag
#         tag_center = (int(tag.center[0]), int(tag.center[1]))
#         cv2.putText(img, str(tag.tag_id), tag_center, cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    for r in results:
        boxes = r.boxes
        for box in boxes:
            # Bounding box coordinates
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)  # Convert to int
            midx = (x1 + x2)/2.0
            midy = (y1 + y2)/2.0
            # Draw the bounding box
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

            # Get the confidence score and class name
            confidence = math.ceil((box.conf[0] * 100)) / 100
            #print("Confidence --->", confidence)

            cls = int(box.cls[0])
            #print("Class name -->", classNames[cls])
            labt = '(' + str(round((midx - base_x)* len_side, 2)) + ", " + str(round((midy - base_y)* len_side, 2)) + ')'
            # Display class name on the bounding box
            org = [x1, y1]
            org2 = [x2, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 255, 0)
            thickness = 2
            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)
            cv2.putText(img, labt, org2, font, fontScale, color, thickness)
    # ---- 3. Display the combined detections ----
    cv2.imshow("Webcam with Model and AprilTag Detection", img)

    # Break the loop when 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the camera and close OpenCV windows
cap.release()
cv2.destroyAllWindows()
cv2.waitKey(1)
# camera.deinit_cam()
# camera.release()
# Out:
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C81C280>
# 0
#
# 0: 384x640 (no detections), 290.6ms
# Speed: 49.3ms preprocess, 290.6ms inference, 233.1ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C82BD78160>
# 0
#
# 0: 384x640 (no detections), 40.2ms
# Speed: 7.1ms preprocess, 40.2ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 38.8ms
# Speed: 6.3ms preprocess, 38.8ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 48.7ms
# Speed: 7.0ms preprocess, 48.7ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 46.3ms
# Speed: 7.4ms preprocess, 46.3ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 74.4ms
# Speed: 10.6ms preprocess, 74.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 42.4ms
# Speed: 6.8ms preprocess, 42.4ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 44.2ms
# Speed: 7.0ms preprocess, 44.2ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 50.4ms
# Speed: 5.3ms preprocess, 50.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 47.5ms
# Speed: 7.6ms preprocess, 47.5ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 42.1ms
# Speed: 7.4ms preprocess, 42.1ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 91.2ms
# Speed: 7.8ms preprocess, 91.2ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 47.2ms
# Speed: 5.9ms preprocess, 47.2ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 48.5ms
# Speed: 7.3ms preprocess, 48.5ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 54.8ms
# Speed: 6.0ms preprocess, 54.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 47.0ms
# Speed: 5.0ms preprocess, 47.0ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 50.6ms
# Speed: 4.8ms preprocess, 50.6ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 52.1ms
# Speed: 6.3ms preprocess, 52.1ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 46.7ms
# Speed: 6.0ms preprocess, 46.7ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 45.8ms
# Speed: 5.5ms preprocess, 45.8ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 49.0ms
# Speed: 5.8ms preprocess, 49.0ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 45.4ms
# Speed: 5.2ms preprocess, 45.4ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 46.6ms
# Speed: 6.1ms preprocess, 46.6ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 45.8ms
# Speed: 5.2ms preprocess, 45.8ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 42.8ms
# Speed: 5.7ms preprocess, 42.8ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 44.4ms
# Speed: 6.3ms preprocess, 44.4ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 52.7ms
# Speed: 5.3ms preprocess, 52.7ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 38.1ms
# Speed: 6.0ms preprocess, 38.1ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 49.6ms
# Speed: 5.8ms preprocess, 49.6ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 49.0ms
# Speed: 6.3ms preprocess, 49.0ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 213.7ms
# Speed: 7.3ms preprocess, 213.7ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 71.9ms
# Speed: 5.5ms preprocess, 71.9ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 45.7ms
# Speed: 6.7ms preprocess, 45.7ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 47.2ms
# Speed: 7.9ms preprocess, 47.2ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 50.5ms
# Speed: 8.5ms preprocess, 50.5ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 41.1ms
# Speed: 5.8ms preprocess, 41.1ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 42.2ms
# Speed: 8.4ms preprocess, 42.2ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 41.8ms
# Speed: 6.6ms preprocess, 41.8ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 53.5ms
# Speed: 7.8ms preprocess, 53.5ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 57.0ms
# Speed: 8.1ms preprocess, 57.0ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 43.0ms
# Speed: 8.4ms preprocess, 43.0ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 36.8ms
# Speed: 8.2ms preprocess, 36.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 38.4ms
# Speed: 7.1ms preprocess, 38.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 46.1ms
# Speed: 7.7ms preprocess, 46.1ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 48.0ms
# Speed: 7.5ms preprocess, 48.0ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 48.2ms
# Speed: 7.7ms preprocess, 48.2ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 55.5ms
# Speed: 7.0ms preprocess, 55.5ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 43.5ms
# Speed: 8.3ms preprocess, 43.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 47.5ms
# Speed: 6.9ms preprocess, 47.5ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 45.6ms
# Speed: 7.3ms preprocess, 45.6ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 39.6ms
# Speed: 6.3ms preprocess, 39.6ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 53.7ms
# Speed: 8.3ms preprocess, 53.7ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 51.0ms
# Speed: 7.8ms preprocess, 51.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 43.5ms
# Speed: 7.1ms preprocess, 43.5ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 40.9ms
# Speed: 8.3ms preprocess, 40.9ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 42.1ms
# Speed: 6.6ms preprocess, 42.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 39.0ms
# Speed: 7.4ms preprocess, 39.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 40.8ms
# Speed: 6.2ms preprocess, 40.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 53.2ms
# Speed: 7.5ms preprocess, 53.2ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 43.8ms
# Speed: 5.0ms preprocess, 43.8ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 48.5ms
# Speed: 6.3ms preprocess, 48.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 35.4ms
# Speed: 5.3ms preprocess, 35.4ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 34.8ms
# Speed: 5.2ms preprocess, 34.8ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 35.7ms
# Speed: 5.0ms preprocess, 35.7ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 41.6ms
# Speed: 6.0ms preprocess, 41.6ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 41.7ms
# Speed: 5.9ms preprocess, 41.7ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 31.1ms
# Speed: 5.3ms preprocess, 31.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 49.5ms
# Speed: 5.5ms preprocess, 49.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 37.4ms
# Speed: 5.4ms preprocess, 37.4ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 94.9ms
# Speed: 6.0ms preprocess, 94.9ms inference, 15.5ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 41.8ms
# Speed: 6.7ms preprocess, 41.8ms inference, 10.4ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 40.1ms
# Speed: 4.8ms preprocess, 40.1ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 1
#
# 0: 384x640 (no detections), 37.2ms
# Speed: 7.3ms preprocess, 37.2ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 1
#
# 0: 384x640 (no detections), 69.2ms
# Speed: 8.0ms preprocess, 69.2ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 1
#
# 0: 384x640 (no detections), 42.0ms
# Speed: 7.8ms preprocess, 42.0ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 1
#
# 0: 384x640 (no detections), 43.0ms
# Speed: 7.2ms preprocess, 43.0ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 1
#
# 0: 384x640 (no detections), 47.0ms
# Speed: 6.8ms preprocess, 47.0ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 43.8ms
# Speed: 7.5ms preprocess, 43.8ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 1
#
# 0: 384x640 (no detections), 60.1ms
# Speed: 7.0ms preprocess, 60.1ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 1
#
# 0: 384x640 (no detections), 71.1ms
# Speed: 6.7ms preprocess, 71.1ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 1
#
# 0: 384x640 (no detections), 63.5ms
# Speed: 7.6ms preprocess, 63.5ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 1
#
# 0: 384x640 (no detections), 46.5ms
# Speed: 7.5ms preprocess, 46.5ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 69.0ms
# Speed: 7.7ms preprocess, 69.0ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 56.1ms
# Speed: 7.0ms preprocess, 56.1ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 1 Ball, 47.5ms
# Speed: 7.6ms preprocess, 47.5ms inference, 688.5ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 1
#
# 0: 384x640 (no detections), 44.2ms
# Speed: 7.5ms preprocess, 44.2ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 1
#
# 0: 384x640 (no detections), 62.3ms
# Speed: 9.5ms preprocess, 62.3ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 1
#
# 0: 384x640 (no detections), 55.4ms
# Speed: 7.4ms preprocess, 55.4ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 1
#
# 0: 384x640 (no detections), 40.8ms
# Speed: 7.7ms preprocess, 40.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 1
#
# 0: 384x640 (no detections), 24.9ms
# Speed: 4.8ms preprocess, 24.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 1
#
# 0: 384x640 (no detections), 24.9ms
# Speed: 4.8ms preprocess, 24.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 1
#
# 0: 384x640 (no detections), 24.8ms
# Speed: 4.8ms preprocess, 24.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 1
#
# 0: 384x640 (no detections), 25.3ms
# Speed: 4.3ms preprocess, 25.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 1
#
# 0: 384x640 (no detections), 24.3ms
# Speed: 6.0ms preprocess, 24.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 1
#
# 0: 384x640 (no detections), 24.5ms
# Speed: 4.6ms preprocess, 24.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 1
#
# 0: 384x640 (no detections), 24.6ms
# Speed: 5.5ms preprocess, 24.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 1
#
# 0: 384x640 (no detections), 17.6ms
# Speed: 4.2ms preprocess, 17.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 31.2ms
# Speed: 5.1ms preprocess, 31.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 29.5ms
# Speed: 4.9ms preprocess, 29.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 21.7ms
# Speed: 4.9ms preprocess, 21.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 19.4ms
# Speed: 3.5ms preprocess, 19.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 20.2ms
# Speed: 3.4ms preprocess, 20.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 17.4ms
# Speed: 3.8ms preprocess, 17.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 17.8ms
# Speed: 3.2ms preprocess, 17.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 17.8ms
# Speed: 3.6ms preprocess, 17.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 17.3ms
# Speed: 3.5ms preprocess, 17.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 30.4ms
# Speed: 4.6ms preprocess, 30.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 0
#
# 0: 384x640 (no detections), 25.2ms
# Speed: 4.1ms preprocess, 25.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 0
#
# 0: 384x640 (no detections), 23.7ms
# Speed: 4.3ms preprocess, 23.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 1
#
# 0: 384x640 (no detections), 32.8ms
# Speed: 4.3ms preprocess, 32.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 1
#
# 0: 384x640 (no detections), 20.5ms
# Speed: 3.5ms preprocess, 20.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 2
#
# 0: 384x640 1 Ball, 18.9ms
# Speed: 3.5ms preprocess, 18.9ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 17.6ms
# Speed: 3.4ms preprocess, 17.6ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 1
#
# 0: 384x640 (no detections), 17.3ms
# Speed: 3.4ms preprocess, 17.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 1
#
# 0: 384x640 (no detections), 17.2ms
# Speed: 3.5ms preprocess, 17.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 1
#
# 0: 384x640 (no detections), 18.7ms
# Speed: 3.4ms preprocess, 18.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 1
#
# 0: 384x640 1 Ball, 19.0ms
# Speed: 3.4ms preprocess, 19.0ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 2
#
# 0: 384x640 1 Ball, 17.9ms
# Speed: 3.6ms preprocess, 17.9ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 17.2ms
# Speed: 3.6ms preprocess, 17.2ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 2
#
# 0: 384x640 1 Ball, 18.1ms
# Speed: 3.6ms preprocess, 18.1ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 16.4ms
# Speed: 3.8ms preprocess, 16.4ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 2
#
# 0: 384x640 1 Ball, 16.8ms
# Speed: 3.3ms preprocess, 16.8ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 18.3ms
# Speed: 4.0ms preprocess, 18.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 1
#
# 0: 384x640 1 Ball, 16.3ms
# Speed: 3.5ms preprocess, 16.3ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 18.3ms
# Speed: 3.6ms preprocess, 18.3ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 2
#
# 0: 384x640 1 Ball, 15.7ms
# Speed: 4.0ms preprocess, 15.7ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 1
#
# 0: 384x640 1 Ball, 18.0ms
# Speed: 3.9ms preprocess, 18.0ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 2
#
# 0: 384x640 1 Ball, 20.0ms
# Speed: 3.9ms preprocess, 20.0ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 23.9ms
# Speed: 4.6ms preprocess, 23.9ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 2
#
# 0: 384x640 1 Ball, 23.9ms
# Speed: 4.6ms preprocess, 23.9ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 19.5ms
# Speed: 3.7ms preprocess, 19.5ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 2
#
# 0: 384x640 (no detections), 16.6ms
# Speed: 3.3ms preprocess, 16.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 18.2ms
# Speed: 3.8ms preprocess, 18.2ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 2
#
# 0: 384x640 1 Ball, 19.3ms
# Speed: 3.3ms preprocess, 19.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 (no detections), 21.4ms
# Speed: 3.4ms preprocess, 21.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 2
#
# 0: 384x640 (no detections), 18.4ms
# Speed: 3.4ms preprocess, 18.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 (no detections), 18.0ms
# Speed: 3.3ms preprocess, 18.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 2
#
# 0: 384x640 (no detections), 16.3ms
# Speed: 3.0ms preprocess, 16.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 (no detections), 18.6ms
# Speed: 3.7ms preprocess, 18.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 2
#
# 0: 384x640 (no detections), 26.4ms
# Speed: 3.2ms preprocess, 26.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 (no detections), 17.0ms
# Speed: 3.8ms preprocess, 17.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 2
#
# 0: 384x640 (no detections), 16.9ms
# Speed: 3.5ms preprocess, 16.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 1
#
# 0: 384x640 (no detections), 16.9ms
# Speed: 3.3ms preprocess, 16.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 1
#
# 0: 384x640 (no detections), 16.4ms
# Speed: 3.5ms preprocess, 16.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 1
#
# 0: 384x640 (no detections), 18.8ms
# Speed: 3.7ms preprocess, 18.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 1
#
# 0: 384x640 (no detections), 18.0ms
# Speed: 3.6ms preprocess, 18.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 1
#
# 0: 384x640 (no detections), 18.0ms
# Speed: 3.6ms preprocess, 18.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 1
#
# 0: 384x640 (no detections), 19.8ms
# Speed: 3.4ms preprocess, 19.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 1
#
# 0: 384x640 (no detections), 17.1ms
# Speed: 3.7ms preprocess, 17.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 1
#
# 0: 384x640 (no detections), 16.8ms
# Speed: 3.7ms preprocess, 16.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 (no detections), 20.4ms
# Speed: 3.5ms preprocess, 20.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 2
#
# 0: 384x640 (no detections), 16.5ms
# Speed: 3.6ms preprocess, 16.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 (no detections), 19.5ms
# Speed: 3.4ms preprocess, 19.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 2
#
# 0: 384x640 (no detections), 21.3ms
# Speed: 3.8ms preprocess, 21.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 1
#
# 0: 384x640 1 Ball, 16.4ms
# Speed: 3.5ms preprocess, 16.4ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 1
#
# 0: 384x640 1 Ball, 17.6ms
# Speed: 3.3ms preprocess, 17.6ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 32.5ms
# Speed: 4.1ms preprocess, 32.5ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 2
#
# 0: 384x640 1 Ball, 18.0ms
# Speed: 3.9ms preprocess, 18.0ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 16.9ms
# Speed: 4.1ms preprocess, 16.9ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C5531C0>
# 2
#
# 0: 384x640 1 Ball, 19.7ms
# Speed: 3.3ms preprocess, 19.7ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 1
#
# 0: 384x640 1 Ball, 20.3ms
# Speed: 3.8ms preprocess, 20.3ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 18.3ms
# Speed: 3.8ms preprocess, 18.3ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 19.4ms
# Speed: 3.7ms preprocess, 19.4ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 19.4ms
# Speed: 4.0ms preprocess, 19.4ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 16.0ms
# Speed: 3.7ms preprocess, 16.0ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 16.8ms
# Speed: 3.4ms preprocess, 16.8ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 25.9ms
# Speed: 4.1ms preprocess, 25.9ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 19.2ms
# Speed: 3.9ms preprocess, 19.2ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 19.1ms
# Speed: 3.7ms preprocess, 19.1ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 21.8ms
# Speed: 3.8ms preprocess, 21.8ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 (no detections), 20.3ms
# Speed: 4.4ms preprocess, 20.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 (no detections), 22.5ms
# Speed: 3.9ms preprocess, 22.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 (no detections), 20.9ms
# Speed: 3.3ms preprocess, 20.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 (no detections), 23.1ms
# Speed: 5.1ms preprocess, 23.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 1
#
# 0: 384x640 (no detections), 26.3ms
# Speed: 5.3ms preprocess, 26.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 20.5ms
# Speed: 3.8ms preprocess, 20.5ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 17.4ms
# Speed: 3.8ms preprocess, 17.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 2 Balls, 17.6ms
# Speed: 3.9ms preprocess, 17.6ms inference, 18.7ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 23.8ms
# Speed: 4.6ms preprocess, 23.8ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 23.6ms
# Speed: 4.4ms preprocess, 23.6ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 18.1ms
# Speed: 3.7ms preprocess, 18.1ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 17.1ms
# Speed: 3.5ms preprocess, 17.1ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 19.6ms
# Speed: 4.5ms preprocess, 19.6ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 1
#
# 0: 384x640 1 Ball, 20.0ms
# Speed: 4.3ms preprocess, 20.0ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 17.6ms
# Speed: 3.4ms preprocess, 17.6ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 17.3ms
# Speed: 3.1ms preprocess, 17.3ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 22.1ms
# Speed: 4.1ms preprocess, 22.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 17.6ms
# Speed: 3.9ms preprocess, 17.6ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 26.5ms
# Speed: 4.8ms preprocess, 26.5ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 21.6ms
# Speed: 4.5ms preprocess, 21.6ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 18.3ms
# Speed: 3.3ms preprocess, 18.3ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 18.5ms
# Speed: 3.5ms preprocess, 18.5ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 16.7ms
# Speed: 4.0ms preprocess, 16.7ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 16.6ms
# Speed: 3.2ms preprocess, 16.6ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 17.3ms
# Speed: 3.7ms preprocess, 17.3ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 27.2ms
# Speed: 3.8ms preprocess, 27.2ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 23.4ms
# Speed: 3.7ms preprocess, 23.4ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 21.8ms
# Speed: 5.1ms preprocess, 21.8ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 26.2ms
# Speed: 3.9ms preprocess, 26.2ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 28.7ms
# Speed: 3.4ms preprocess, 28.7ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 (no detections), 29.6ms
# Speed: 4.4ms preprocess, 29.6ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 (no detections), 29.2ms
# Speed: 5.0ms preprocess, 29.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 (no detections), 24.2ms
# Speed: 4.7ms preprocess, 24.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 (no detections), 20.8ms
# Speed: 3.5ms preprocess, 20.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 (no detections), 20.3ms
# Speed: 4.3ms preprocess, 20.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 (no detections), 17.4ms
# Speed: 3.6ms preprocess, 17.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 1
#
# 0: 384x640 (no detections), 17.6ms
# Speed: 3.9ms preprocess, 17.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 1
#
# 0: 384x640 (no detections), 16.6ms
# Speed: 3.3ms preprocess, 16.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 (no detections), 15.5ms
# Speed: 3.6ms preprocess, 15.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 (no detections), 20.7ms
# Speed: 3.9ms preprocess, 20.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 (no detections), 20.7ms
# Speed: 4.6ms preprocess, 20.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 (no detections), 19.3ms
# Speed: 3.7ms preprocess, 19.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 (no detections), 20.5ms
# Speed: 4.4ms preprocess, 20.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 (no detections), 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 18.6ms
# Speed: 3.7ms preprocess, 18.6ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 23.9ms
# Speed: 5.3ms preprocess, 23.9ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 23.6ms
# Speed: 4.5ms preprocess, 23.6ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 24.1ms
# Speed: 4.9ms preprocess, 24.1ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 20.5ms
# ...
# 2
#
# 0: 384x640 1 Ball, 21.8ms
# Speed: 3.5ms preprocess, 21.8ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 18.3ms
# Speed: 3.1ms preprocess, 18.3ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 17.3ms
# Speed: 3.5ms preprocess, 17.3ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 17.3ms
# Speed: 3.1ms preprocess, 17.3ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 20.7ms
# Speed: 3.5ms preprocess, 20.7ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 31.4ms
# Speed: 4.1ms preprocess, 31.4ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 24.4ms
# Speed: 4.1ms preprocess, 24.4ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 19.4ms
# Speed: 3.4ms preprocess, 19.4ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 15.9ms
# Speed: 3.2ms preprocess, 15.9ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 22.4ms
# Speed: 3.4ms preprocess, 22.4ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 26.9ms
# Speed: 4.3ms preprocess, 26.9ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 18.3ms
# Speed: 3.9ms preprocess, 18.3ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 17.0ms
# Speed: 4.3ms preprocess, 17.0ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 19.3ms
# Speed: 3.6ms preprocess, 19.3ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 18.3ms
# Speed: 3.5ms preprocess, 18.3ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 23.2ms
# Speed: 5.3ms preprocess, 23.2ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 26.7ms
# Speed: 4.6ms preprocess, 26.7ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 25.8ms
# Speed: 5.3ms preprocess, 25.8ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 29.7ms
# Speed: 4.8ms preprocess, 29.7ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 29.9ms
# Speed: 5.4ms preprocess, 29.9ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 2 Balls, 25.6ms
# Speed: 4.7ms preprocess, 25.6ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 29.6ms
# Speed: 5.3ms preprocess, 29.6ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 25.4ms
# Speed: 5.6ms preprocess, 25.4ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 27.9ms
# Speed: 5.1ms preprocess, 27.9ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 23.4ms
# Speed: 4.4ms preprocess, 23.4ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 28.4ms
# Speed: 3.8ms preprocess, 28.4ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 18.1ms
# Speed: 3.7ms preprocess, 18.1ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 16.6ms
# Speed: 3.5ms preprocess, 16.6ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 1
#
# 0: 384x640 1 Ball, 28.4ms
# Speed: 3.5ms preprocess, 28.4ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 17.2ms
# Speed: 3.4ms preprocess, 17.2ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 19.7ms
# Speed: 4.1ms preprocess, 19.7ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 20.1ms
# Speed: 4.4ms preprocess, 20.1ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 28.6ms
# Speed: 4.0ms preprocess, 28.6ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 20.5ms
# Speed: 4.2ms preprocess, 20.5ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 26.3ms
# Speed: 5.0ms preprocess, 26.3ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 26.9ms
# Speed: 5.2ms preprocess, 26.9ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 31.5ms
# Speed: 4.2ms preprocess, 31.5ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 25.8ms
# Speed: 4.6ms preprocess, 25.8ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 28.5ms
# Speed: 4.4ms preprocess, 28.5ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 16.0ms
# Speed: 4.3ms preprocess, 16.0ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 26.9ms
# Speed: 4.5ms preprocess, 26.9ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 1
#
# 0: 384x640 1 Ball, 22.8ms
# Speed: 4.0ms preprocess, 22.8ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 22.1ms
# Speed: 3.7ms preprocess, 22.1ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 17.0ms
# Speed: 3.4ms preprocess, 17.0ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 16.7ms
# Speed: 3.5ms preprocess, 16.7ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 17.3ms
# Speed: 4.1ms preprocess, 17.3ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 2 Balls, 25.7ms
# Speed: 4.5ms preprocess, 25.7ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 2 Balls, 23.8ms
# Speed: 4.9ms preprocess, 23.8ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 2 Balls, 33.2ms
# Speed: 4.1ms preprocess, 33.2ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 29.7ms
# Speed: 4.7ms preprocess, 29.7ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 24.8ms
# Speed: 4.2ms preprocess, 24.8ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 24.2ms
# Speed: 5.0ms preprocess, 24.2ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 29.9ms
# Speed: 4.2ms preprocess, 29.9ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 16.8ms
# Speed: 3.5ms preprocess, 16.8ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 26.7ms
# Speed: 5.2ms preprocess, 26.7ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 26.7ms
# Speed: 4.0ms preprocess, 26.7ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 25.8ms
# Speed: 4.1ms preprocess, 25.8ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 26.8ms
# Speed: 3.5ms preprocess, 26.8ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 1
#
# 0: 384x640 1 Ball, 18.7ms
# Speed: 3.6ms preprocess, 18.7ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 1
#
# 0: 384x640 1 Ball, 16.6ms
# Speed: 3.3ms preprocess, 16.6ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 1
#
# 0: 384x640 1 Ball, 16.7ms
# Speed: 3.7ms preprocess, 16.7ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 16.9ms
# Speed: 3.2ms preprocess, 16.9ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 33.3ms
# Speed: 5.2ms preprocess, 33.3ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 22.2ms
# Speed: 5.0ms preprocess, 22.2ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 29.5ms
# Speed: 5.3ms preprocess, 29.5ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 1
#
# 0: 384x640 1 Ball, 27.5ms
# Speed: 4.6ms preprocess, 27.5ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 1
#
# 0: 384x640 1 Ball, 31.3ms
# Speed: 4.1ms preprocess, 31.3ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 1
#
# 0: 384x640 1 Ball, 27.9ms
# Speed: 5.8ms preprocess, 27.9ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 1
#
# 0: 384x640 1 Ball, 24.9ms
# Speed: 5.0ms preprocess, 24.9ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 2
#
# 0: 384x640 1 Ball, 25.5ms
# Speed: 5.7ms preprocess, 25.5ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 2
#
# 0: 384x640 1 Ball, 27.7ms
# Speed: 4.9ms preprocess, 27.7ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 1
#
# 0: 384x640 1 Ball, 28.5ms
# Speed: 3.5ms preprocess, 28.5ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 1
#
# 0: 384x640 1 Ball, 19.2ms
# Speed: 3.3ms preprocess, 19.2ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 1
#
# 0: 384x640 1 Ball, 16.9ms
# Speed: 3.5ms preprocess, 16.9ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C86CEE2200>
# 1
#
# 0: 384x640 1 Ball, 17.8ms
# Speed: 3.4ms preprocess, 17.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# (720, 1280, 3)
# <generator object BasePredictor.stream_inference at 0x000001C87C553640>
# 1

# %%
camera.deinit_cam()
camera.release()
